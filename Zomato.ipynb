# %% [markdown]
# <a href="https://colab.research.google.com/github/dWanderingSoul/Zomato/blob/main/Zomato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-e276e53a-e2b7-4d52-b548-dbf824be3b6f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e276e53a-e2b7-4d52-b548-dbf824be3b6f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pip install pandas-profiling sweetviz
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 84.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 26.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 41.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 85.0 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=dcd655710c1f0da94af2b32ebcfca60764e9225de226b5c364b7ad9ccf9598dc
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
# !pip install -U pandas-profiling[notebook]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.5 MB/s eta 0:00:00
# ...

# %%
# !pip install pydantic-settings

# %%
# !pip install -U pandas-profiling pydantic-settings

# %%
import pandas as pd
from pandas_profiling import ProfileReport

# Load the dataset
data = pd.read_csv("zomato.csv")

# Generate Pandas Profiling report
profile = ProfileReport(data, title="Pandas Profiling Report", explorative=True)
profile.to_file("pandas_profiling_report.html")
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# <ipython-input-10-7fa791cda3d7> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 from pandas_profiling import ProfileReport
#       3
#       4 # Load the dataset
#       5 data = pd.read_csv("zomato.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas_profiling/__init__.py in <module>
#       6 from warnings import warn
#       7
# ----> 8 from pandas_profiling.compare_reports import compare
#       9 from pandas_profiling.controller import pandas_decorator
#      10 from pandas_profiling.profile_report import ProfileReport
#
# /usr/local/lib/python3.10/dist-packages/pandas_profiling/compare_reports.py in <module>
#       4 import pandas as pd
#       5
# ----> 6 from pandas_profiling.config import Correlation, Settings
#       7 from pandas_profiling.model.alerts import Alert
# ...

# %%
# !pip install -U ydata-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport # Updated import statement

# Load the dataset
data = pd.read_csv("zomato.csv")

# Generate Pandas Profiling report
profile = ProfileReport(data, title="Pandas Profiling Report", explorative=True)
profile.to_file("pandas_profiling_report.html")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-12-ee9f60f8ceed> in <cell line: 5>()
#       3
#       4 # Load the dataset
# ----> 5 data = pd.read_csv("zomato.csv")
#       6
#       7 # Generate Pandas Profiling report
#
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load the dataset, specifying the encoding
data = pd.read_csv("zomato.csv", encoding='latin-1') # or 'ISO-8859-1', 'cp1252', etc.

# Generate Pandas Profiling report
profile = ProfileReport(data, title="Pandas Profiling Report", explorative=True)
profile.to_file("pandas_profiling_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import sweetviz as sv

# Create SweetViz report
report = sv.analyze(data)
report.show_html("sweetviz_report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# /usr/local/lib/python3.10/dist-packages/sweetviz/graph.py:33: UserWarning: Glyph 140 (\x8c) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# /usr/local/lib/python3.10/dist-packages/sweetviz/graph.py:33: UserWarning: Glyph 140 (\x8c) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# prompt: save reports

from google.colab import files

files.download('pandas_profiling_report.html')
files.download('sweetviz_report.html')

# %%
# prompt: Interpret Results and Gain Insights:
# Analyze the Pandas Profiling report and SweetViz visualizations to identify patterns, outliers, and relationships in the data.
# Use these insights to make informed decisions about data cleaning, feature engineering, and modeling.

# Load the Pandas Profiling report and SweetViz report (you've already downloaded them)
# You can open these HTML files in your browser to view the reports.

# Based on the reports, you can identify patterns, outliers, and relationships in the data.

# Example insights and actions:

# 1. Missing Data:
#   - If the reports show a high percentage of missing values in certain columns, you might
#     consider:
#       - Imputing missing values with mean, median, or mode.
#       - Dropping columns with a high percentage of missing values.
#       - Investigating the reasons for missing data and potentially collecting it again.

# 2. Outliers:
#   - If the reports show outliers in certain variables, you might consider:
#       - Removing outliers if they are likely due to data entry errors or measurement issues.
#       - Transforming variables to reduce the impact of outliers (e.g., log transformation).
#       - Treating outliers as a separate category or group.

# 3. Relationships:
#   - The reports can show correlations between variables. You can use this information to:
#       - Identify features that are strongly correlated with the target variable (for supervised learning).
#       - Identify redundant features that can be removed.

# 4. Data Types:
#   - The reports can show the data types of each column. You might need to convert columns to
#     the appropriate data type for analysis. For example, date/time columns might need to be
#     converted to datetime objects.

# 5. Feature Engineering:
#   - You can use the insights from the reports to create new features. For example, you might
#     create interaction terms between variables that are strongly correlated.

# 6. Modeling:
#   - You can use the insights from the reports to choose appropriate models for your data. For
#     example, if your data has a lot of outliers, you might consider using a robust model.


# Example: Analyze Correlation Matrix
# You can use the correlation matrix from the Pandas Profiling report to identify strong
# correlations. For example:
# if data['column1'].corr(data['column2']) > 0.8:
#   print("Column1 and Column2 are highly correlated.")


# Example: Analyze Missing Values
# You can use the missing value information from the Pandas Profiling report to identify
# columns with missing values.
# for column in data.columns:
#   if data[column].isnull().sum() > 0:
#     print(f"Column {column} has missing values.")


# Example: Analyze Outliers
# You can use the descriptive statistics and histograms from the Pandas Profiling report to
# identify outliers.
# For example:
# for column in data.columns:
#   if pd.api.types.is_numeric_dtype(data[column]):
#     q1 = data[column].quantile(0.25)
#     q3 = data[column].quantile(0.75)
#     iqr = q3 - q1
#     lower_bound = q1 - 1.5 * iqr
#     upper_bound = q3 + 1.5 * iqr
#     outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
#     if not outliers.empty:
#       print(f"Column {column} has outliers.")


# After analyzing the reports, you can apply data cleaning, feature engineering, and modeling
# techniques to your dataset.
